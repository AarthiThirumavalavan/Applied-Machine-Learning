# %% [markdown]
# Contents:
#
#
# 1.   Imports
# 2.   Dataset preparation
#
# 3.   Model building
# 4.   Model evaluation

# %% [markdown]
# (1) Imports

# %%
#IMPORTS
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from keras import layers
from keras import optimizers
from keras import models
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import BatchNormalization
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import tarfile
import os
import cv2
import numpy as np
import pandas as pd

# %% [markdown]
# (2) Dataset preparation

# %%
#DATASET EXTRACTION
tar = tarfile.open('/content/drive/MyDrive/Appsilon_Assignment/working/17flowers.tgz','r')
tar.extractall()

# %%
#ONE HOT ENCODING FOR THE 17 CATEGORIES
classes = [ i for i in range(0,17) ]
y = np.repeat(classes, 80)
y = tf.keras.utils.to_categorical(y, num_classes=17, dtype='float32')

# %%
#DATA PREPARATION
images = []
loc = os.path.expanduser('/content/drive/MyDrive/Appsilon_Assignment/working/jpg')

for filename in sorted(os.listdir(loc)):

    img = cv2.imread(os.path.join(loc,filename))

    if img is not None:
        img = cv2.resize(img, dsize=(224, 224))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        images.append(img)

images = np.asarray(images)

# %%
#DATASET SPLIT INTO TRAIN AND VALIDATION SET IN 80:20 RATIO
X_train, X_val, y_train, y_val = train_test_split(images, y, test_size=0.2, random_state=0)

# %%
#PLOTTING FIRST FEW IMAGES
for i in range(9):
	plt.subplot(330 + 1 + i)
	plt.imshow(X_train[i])
plt.show()

# %%
#IMAGE SIZE
images.shape
# Out:
# (1360, 224, 224, 3)

# %%
#DATA AUGMENTATION
train_datagen = ImageDataGenerator (rescale=1./255,
                                    brightness_range=[0.1, 0.7],
                                    featurewise_std_normalization=True,
                                    zoom_range=0.2,
                                    rotation_range=90,
                                    width_shift_range=0.2,
                                    height_shift_range=0.2,
                                    horizontal_flip=True,
                                    fill_mode='nearest')

val_datagen = ImageDataGenerator (rescale=1./255, featurewise_std_normalization=True)

train_generator = train_datagen.flow(X_train, y_train, batch_size=32)
val_generator = val_datagen.flow(X_val, y_val, batch_size=32)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:349: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %% [markdown]
# (3) Model building

# %%
#IMPORTING VGG16 LIBRARY
conv_base = VGG16(weights='imagenet',include_top=False, input_shape=(224, 224, 3))

# %%
#RETAINING EXISTING WEIGHTS OF THE MODEL
for layer in conv_base.layers:
  layer.trainable = False

# %%
#BUILDING SEQUENTIAL MODEL BY ADDING LAYERS
model = models.Sequential()
model.add(conv_base)
model.add(layers.Conv2D(filters=64, kernel_initializer='he_uniform', kernel_size=(3,3),padding="same", activation="relu"))
model.add(layers.Conv2D(filters=64, kernel_initializer='he_uniform', kernel_size=(3,3),padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_initializer='he_uniform', kernel_size=(3,3),padding="same", activation="relu"))
model.add(layers.Conv2D(filters=64,kernel_initializer='he_uniform', kernel_size=(3,3),padding="same", activation="relu"))
model.add(BatchNormalization())
model.add(layers.MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.2))
model.add(layers.Dense(512, activation='relu', kernel_initializer='he_uniform'))
model.add(layers.Dense(512, activation='relu', kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(layers.Dense(17, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  conv2d_10 (Conv2D)          (None, 7, 7, 64)          294976
#
#  conv2d_11 (Conv2D)          (None, 7, 7, 64)          36928
#
#  batch_normalization_3 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 3, 3, 64)          36928
#
#  conv2d_13 (Conv2D)          (None, 3, 3, 64)          36928
#
#  batch_normalization_4 (Batc  (None, 3, 3, 64)         256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 64)                0
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 512)               33280
#
#  dense_7 (Dense)             (None, 512)               262656
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_8 (Dense)             (None, 17)                8721
#
# =================================================================
# Total params: 15,427,665
# Trainable params: 711,697
# Non-trainable params: 14,715,968
# _________________________________________________________________

# %% [markdown]
# (4) Model evaluation

# %%
#MODEL CHECKPOINT CALLBACK
checkpointer = ModelCheckpoint(filepath='/content/drive/MyDrive/Appsilon_Assignment/model/final_model_best.hdf5',
                                  save_best_only=True,
                                  verbose=1)

#EARLY STOPPING
early_stop = EarlyStopping(monitor='val_loss',
                           patience=10,
                           restore_best_weights=True,
                           mode='min')

# %%
batch_size = 32
ntrain = len(X_train)
nval = len(X_val)

#COMPILE AND FIT MODEL
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, epsilon=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit_generator(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    steps_per_epoch = ntrain // batch_size,
    validation_steps = nval // batch_size
)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:728: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/100
# 34/34 [==============================] - 21s 589ms/step - loss: 2.8308 - accuracy: 0.1857 - val_loss: 6.2972 - val_accuracy: 0.0938
# Epoch 2/100
# 34/34 [==============================] - 14s 401ms/step - loss: 2.0848 - accuracy: 0.3355 - val_loss: 6.1285 - val_accuracy: 0.1289
# Epoch 3/100
# 34/34 [==============================] - 14s 401ms/step - loss: 1.6411 - accuracy: 0.4550 - val_loss: 2.4223 - val_accuracy: 0.4141
# Epoch 4/100
# 34/34 [==============================] - 14s 408ms/step - loss: 1.4453 - accuracy: 0.5496 - val_loss: 5.2346 - val_accuracy: 0.2070
# Epoch 5/100
# 34/34 [==============================] - 14s 402ms/step - loss: 1.1646 - accuracy: 0.6259 - val_loss: 2.6205 - val_accuracy: 0.3203
# Epoch 6/100
# 34/34 [==============================] - 16s 464ms/step - loss: 1.1179 - accuracy: 0.6415 - val_loss: 3.0487 - val_accuracy: 0.3398
# Epoch 7/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.9618 - accuracy: 0.6893 - val_loss: 1.3239 - val_accuracy: 0.6094
# Epoch 8/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.8805 - accuracy: 0.7215 - val_loss: 1.4542 - val_accuracy: 0.6094
# Epoch 9/100
# 34/34 [==============================] - 14s 413ms/step - loss: 0.7855 - accuracy: 0.7417 - val_loss: 1.1895 - val_accuracy: 0.6562
# Epoch 10/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.6819 - accuracy: 0.7730 - val_loss: 1.6727 - val_accuracy: 0.6172
# Epoch 11/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.7358 - accuracy: 0.7574 - val_loss: 1.0936 - val_accuracy: 0.6836
# Epoch 12/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.6383 - accuracy: 0.7914 - val_loss: 1.8737 - val_accuracy: 0.5625
# Epoch 13/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.6595 - accuracy: 0.7822 - val_loss: 1.0014 - val_accuracy: 0.7734
# Epoch 14/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.6241 - accuracy: 0.7923 - val_loss: 1.3132 - val_accuracy: 0.6797
# Epoch 15/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.5095 - accuracy: 0.8263 - val_loss: 1.0891 - val_accuracy: 0.7305
# Epoch 16/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.5413 - accuracy: 0.8244 - val_loss: 2.0000 - val_accuracy: 0.5312
# Epoch 17/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.5333 - accuracy: 0.8171 - val_loss: 1.2564 - val_accuracy: 0.6836
# Epoch 18/100
# 34/34 [==============================] - 14s 395ms/step - loss: 0.4994 - accuracy: 0.8364 - val_loss: 0.8140 - val_accuracy: 0.7891
# Epoch 19/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.4820 - accuracy: 0.8410 - val_loss: 1.7398 - val_accuracy: 0.6719
# Epoch 20/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.5102 - accuracy: 0.8382 - val_loss: 2.0002 - val_accuracy: 0.6094
# Epoch 21/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.4254 - accuracy: 0.8621 - val_loss: 0.7883 - val_accuracy: 0.7891
# Epoch 22/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.4455 - accuracy: 0.8566 - val_loss: 1.2468 - val_accuracy: 0.6680
# Epoch 23/100
# 34/34 [==============================] - 14s 396ms/step - loss: 0.4227 - accuracy: 0.8640 - val_loss: 1.2849 - val_accuracy: 0.6914
# Epoch 24/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.4264 - accuracy: 0.8529 - val_loss: 1.0314 - val_accuracy: 0.7773
# Epoch 25/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3946 - accuracy: 0.8658 - val_loss: 0.7114 - val_accuracy: 0.7969
# Epoch 26/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.3677 - accuracy: 0.8805 - val_loss: 1.4974 - val_accuracy: 0.6875
# Epoch 27/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.4373 - accuracy: 0.8483 - val_loss: 0.7452 - val_accuracy: 0.8047
# Epoch 28/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3689 - accuracy: 0.8805 - val_loss: 0.9250 - val_accuracy: 0.7461
# Epoch 29/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.3794 - accuracy: 0.8732 - val_loss: 1.0374 - val_accuracy: 0.7539
# Epoch 30/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.4056 - accuracy: 0.8511 - val_loss: 0.9932 - val_accuracy: 0.7734
# Epoch 31/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3556 - accuracy: 0.8814 - val_loss: 0.7193 - val_accuracy: 0.8164
# Epoch 32/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.3442 - accuracy: 0.8980 - val_loss: 1.0798 - val_accuracy: 0.7188
# Epoch 33/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.3076 - accuracy: 0.8934 - val_loss: 0.9463 - val_accuracy: 0.7891
# Epoch 34/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.3324 - accuracy: 0.8879 - val_loss: 0.9491 - val_accuracy: 0.7422
# Epoch 35/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3621 - accuracy: 0.8787 - val_loss: 1.2003 - val_accuracy: 0.7109
# Epoch 36/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.3561 - accuracy: 0.8879 - val_loss: 1.7340 - val_accuracy: 0.6797
# Epoch 37/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2704 - accuracy: 0.8998 - val_loss: 1.2891 - val_accuracy: 0.7266
# Epoch 38/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3287 - accuracy: 0.8842 - val_loss: 1.1757 - val_accuracy: 0.7188
# Epoch 39/100
# 34/34 [==============================] - 14s 405ms/step - loss: 0.3108 - accuracy: 0.8888 - val_loss: 0.9665 - val_accuracy: 0.7969
# Epoch 40/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2729 - accuracy: 0.9026 - val_loss: 1.0242 - val_accuracy: 0.7617
# Epoch 41/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.3018 - accuracy: 0.8971 - val_loss: 0.8506 - val_accuracy: 0.8047
# Epoch 42/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.3211 - accuracy: 0.8915 - val_loss: 0.9456 - val_accuracy: 0.7461
# Epoch 43/100
# 34/34 [==============================] - 14s 396ms/step - loss: 0.2733 - accuracy: 0.9090 - val_loss: 1.1873 - val_accuracy: 0.7578
# Epoch 44/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2800 - accuracy: 0.9108 - val_loss: 0.8769 - val_accuracy: 0.7852
# Epoch 45/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2853 - accuracy: 0.9173 - val_loss: 0.8861 - val_accuracy: 0.7891
# Epoch 46/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2362 - accuracy: 0.9246 - val_loss: 0.6783 - val_accuracy: 0.8086
# Epoch 47/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2236 - accuracy: 0.9237 - val_loss: 1.7354 - val_accuracy: 0.6094
# Epoch 48/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2856 - accuracy: 0.9044 - val_loss: 0.6994 - val_accuracy: 0.8242
# Epoch 49/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2527 - accuracy: 0.9182 - val_loss: 0.9989 - val_accuracy: 0.8008
# Epoch 50/100
# 34/34 [==============================] - 14s 408ms/step - loss: 0.2409 - accuracy: 0.9173 - val_loss: 0.9398 - val_accuracy: 0.7891
# Epoch 51/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2702 - accuracy: 0.9182 - val_loss: 1.2105 - val_accuracy: 0.7344
# Epoch 52/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2226 - accuracy: 0.9274 - val_loss: 0.9330 - val_accuracy: 0.7773
# Epoch 53/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2365 - accuracy: 0.9237 - val_loss: 0.6490 - val_accuracy: 0.8477
# Epoch 54/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2284 - accuracy: 0.9256 - val_loss: 1.5516 - val_accuracy: 0.6875
# Epoch 55/100
# 34/34 [==============================] - 14s 396ms/step - loss: 0.2784 - accuracy: 0.9053 - val_loss: 1.3372 - val_accuracy: 0.7383
# Epoch 56/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2259 - accuracy: 0.9228 - val_loss: 1.1910 - val_accuracy: 0.7344
# Epoch 57/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2201 - accuracy: 0.9320 - val_loss: 0.7148 - val_accuracy: 0.8320
# Epoch 58/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.2329 - accuracy: 0.9210 - val_loss: 1.1354 - val_accuracy: 0.7734
# Epoch 59/100
# 34/34 [==============================] - 14s 395ms/step - loss: 0.2276 - accuracy: 0.9274 - val_loss: 1.5805 - val_accuracy: 0.7148
# Epoch 60/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2164 - accuracy: 0.9320 - val_loss: 1.2572 - val_accuracy: 0.7500
# Epoch 61/100
# 34/34 [==============================] - 14s 405ms/step - loss: 0.2321 - accuracy: 0.9210 - val_loss: 1.2970 - val_accuracy: 0.7383
# Epoch 62/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.2631 - accuracy: 0.9090 - val_loss: 0.8195 - val_accuracy: 0.8242
# Epoch 63/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.1955 - accuracy: 0.9347 - val_loss: 0.9481 - val_accuracy: 0.7695
# Epoch 64/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2180 - accuracy: 0.9265 - val_loss: 0.6224 - val_accuracy: 0.8516
# Epoch 65/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2229 - accuracy: 0.9301 - val_loss: 0.6401 - val_accuracy: 0.8477
# Epoch 66/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.2070 - accuracy: 0.9320 - val_loss: 0.8764 - val_accuracy: 0.8242
# Epoch 67/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.2275 - accuracy: 0.9256 - val_loss: 0.7506 - val_accuracy: 0.7891
# Epoch 68/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.1719 - accuracy: 0.9439 - val_loss: 0.7155 - val_accuracy: 0.8398
# Epoch 69/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.1638 - accuracy: 0.9485 - val_loss: 0.9403 - val_accuracy: 0.8086
# Epoch 70/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.1910 - accuracy: 0.9384 - val_loss: 0.6950 - val_accuracy: 0.8359
# Epoch 71/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.1867 - accuracy: 0.9357 - val_loss: 0.7323 - val_accuracy: 0.8281
# Epoch 72/100
# 34/34 [==============================] - 14s 406ms/step - loss: 0.1625 - accuracy: 0.9522 - val_loss: 1.5419 - val_accuracy: 0.6602
# Epoch 73/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.2085 - accuracy: 0.9292 - val_loss: 0.9934 - val_accuracy: 0.7852
# Epoch 74/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2078 - accuracy: 0.9338 - val_loss: 0.7590 - val_accuracy: 0.8555
# Epoch 75/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.1959 - accuracy: 0.9366 - val_loss: 1.1666 - val_accuracy: 0.7930
# Epoch 76/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1830 - accuracy: 0.9366 - val_loss: 1.5105 - val_accuracy: 0.7266
# Epoch 77/100
# 34/34 [==============================] - 14s 396ms/step - loss: 0.1676 - accuracy: 0.9504 - val_loss: 1.1586 - val_accuracy: 0.7734
# Epoch 78/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.1987 - accuracy: 0.9375 - val_loss: 0.9489 - val_accuracy: 0.7930
# Epoch 79/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.2002 - accuracy: 0.9375 - val_loss: 0.7344 - val_accuracy: 0.8359
# Epoch 80/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.1726 - accuracy: 0.9412 - val_loss: 1.2223 - val_accuracy: 0.7852
# Epoch 81/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2266 - accuracy: 0.9265 - val_loss: 0.6854 - val_accuracy: 0.8555
# Epoch 82/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.2069 - accuracy: 0.9375 - val_loss: 1.0684 - val_accuracy: 0.8164
# Epoch 83/100
# 34/34 [==============================] - 14s 402ms/step - loss: 0.1892 - accuracy: 0.9421 - val_loss: 1.5781 - val_accuracy: 0.7305
# Epoch 84/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.1562 - accuracy: 0.9522 - val_loss: 0.5015 - val_accuracy: 0.8594
# Epoch 85/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.1607 - accuracy: 0.9476 - val_loss: 0.9596 - val_accuracy: 0.7734
# Epoch 86/100
# 34/34 [==============================] - 14s 395ms/step - loss: 0.1661 - accuracy: 0.9439 - val_loss: 0.7011 - val_accuracy: 0.8555
# Epoch 87/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.1678 - accuracy: 0.9421 - val_loss: 1.0730 - val_accuracy: 0.7812
# Epoch 88/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.1372 - accuracy: 0.9568 - val_loss: 0.5444 - val_accuracy: 0.8633
# Epoch 89/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1455 - accuracy: 0.9476 - val_loss: 0.7300 - val_accuracy: 0.8398
# Epoch 90/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1864 - accuracy: 0.9403 - val_loss: 1.2214 - val_accuracy: 0.7422
# Epoch 91/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.1846 - accuracy: 0.9403 - val_loss: 0.8995 - val_accuracy: 0.8203
# Epoch 92/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1598 - accuracy: 0.9485 - val_loss: 0.8670 - val_accuracy: 0.7891
# Epoch 93/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.1831 - accuracy: 0.9403 - val_loss: 0.5591 - val_accuracy: 0.8555
# Epoch 94/100
# 34/34 [==============================] - 14s 405ms/step - loss: 0.1504 - accuracy: 0.9504 - val_loss: 0.6893 - val_accuracy: 0.8359
# Epoch 95/100
# 34/34 [==============================] - 16s 477ms/step - loss: 0.1328 - accuracy: 0.9568 - val_loss: 1.1280 - val_accuracy: 0.7578
# Epoch 96/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.1885 - accuracy: 0.9384 - val_loss: 1.0542 - val_accuracy: 0.7695
# Epoch 97/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.1450 - accuracy: 0.9504 - val_loss: 0.8580 - val_accuracy: 0.8281
# Epoch 98/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1513 - accuracy: 0.9494 - val_loss: 0.6189 - val_accuracy: 0.8711
# Epoch 99/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.1603 - accuracy: 0.9531 - val_loss: 0.7803 - val_accuracy: 0.8086
# Epoch 100/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.1611 - accuracy: 0.9430 - val_loss: 0.9686 - val_accuracy: 0.8086

# %%
#SUMMARIZE DIAGNOSTICS
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
plt.xlabel("Epoch #")
plt.ylabel("Loss");
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot()
plt.xlabel("Epoch #")
plt.ylabel("Accuracy");
